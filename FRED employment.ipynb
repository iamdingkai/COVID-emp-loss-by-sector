# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from fredapi import Fred

fred=Fred(api_key='59f9965fe5ba617c83bc86137e478a6a')

# %%
# weekly unemployment Continued Claims
d['claims']=fred.get_series('CCSA',observation_start='2020-02-01')

fig,ax=plt.subplots()
ax.plot_date(d.index,d,fmt='-o',color='blue',label='weekly unemployment claims')
plt.title('weekly UE claims')
plt.grid('minor')
legend=ax.legend(loc='upper left',shadow=True)

# %%
# vacancies and unemployment

d=pd.DataFrame()
d['v']=fred.get_series('LMJVTTUVUSM647S')/1e6
d['u']=fred.get_series('UNEMPLOY')*1e3/1e6

# %matplotlib notebook

plt.plot(d.index,d.v,'bo-',d.index,d.u,'ro-')
plt.grid('minor')
plt.legend(['v','u'])
plt.xlim(datetime.date(2020,2,1),)
# Out:
# <img src="data:image/png;base64,..." width="756">

# %%
# employment by sector

d=pd.DataFrame()
d['manu']=fred.get_series('MANEMP')/1e3
d['cons']=fred.get_series('USCONS')/1e3
d['leihosp']=fred.get_series('USLAH')/1e3
d['retail trade']=fred.get_series('USTRADE')/1e3
d['financial']=fred.get_series('USFIRE')/1e3
d['prof bus']=fred.get_series('USPBS')/1e3
d['health care']=fred.get_series('CES6562000101')/1e3
d['resid building']=fred.get_series('CES2023610001')/1e3

# %%
d.plot(marker='.',subplots=True,grid='minor',layout=(3,3))
plt.xlim(datetime.date(2020,1,1),datetime.date(2021,7,1))
# Out:
# <img src="data:image/png;base64,..." width="978">
# (737425.0, 737972.0)

# %%
d2020=d[d.index=='2020-01-01']
d2020

dnorm=(d.div(d2020.iloc[0])-1)*100


#plt.plot(dnorm,'o-')

temp=dnorm[dnorm.index>'2006-01-01']
temp.plot(marker='.',subplots=True,layout=(3,3),grid='minor')
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="974.6666666666666">
# No handles with labels found to put in legend.
